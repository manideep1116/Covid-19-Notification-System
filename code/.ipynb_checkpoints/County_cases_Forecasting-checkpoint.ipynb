# %% [markdown]
# # Time Series Forecasting for Covid-19 daily new  cases in St. Louis County using  Prophet

# %%
# Python
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import numpy as np
from fbprophet import Prophet
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cases.csv')
print(df)
# Out:
#     State  County  Zip        Date
# 0    1267     387   13  08/13/2020
# 1    1245     289   10  08/14/2020
# 2    1127     256    7  08/15/2020
# 3    1342     187    5  08/16/2020
# 4    1148     150    9  08/17/2020
# ..    ...     ...  ...         ...
# 88   3876     605  202    12/07/20
# 89   2658     617  200    12/08/20
# 90   3250     591  195    12/09/20
# 91   2640     447  191    12/10/20
# 92   3858     409  182    12/11/20
#
# [93 rows x 4 columns]

# %%
df_Co = df[["Date","County"]]
df_Co = df_Co.rename(columns={'County': 'y', 'Date': 'ds'})
df_Co.head()
# Out:
#            ds    y
# 0  08/13/2020  387
# 1  08/14/2020  289
# 2  08/15/2020  256
# 3  08/16/2020  187
# 4  08/17/2020  150

# %%
train_data = df_Co.iloc[:len(df_Co)-10]
test_data = df_Co.iloc[len(df_Co)-10:]
print(test_data)
# Out:
#           ds    y
# 83  12/01/20  602
# 84  12/03/20  572
# 85  12/04/20  695
# 86  12/05/20  688
# 87  12/06/20  902
# 88  12/07/20  605
# 89  12/08/20  617
# 90  12/09/20  591
# 91  12/10/20  447
# 92  12/11/20  409

# %%
m = Prophet()
m.fit(train_data)
future = m.make_future_dataframe(periods=10)
prophet_pred = m.predict(future)
prophet_pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#            ds        yhat  yhat_lower   yhat_upper
# 88 2020-12-06  738.942483  543.749060   897.821644
# 89 2020-12-07  731.135316  570.153235   918.046618
# 90 2020-12-08  861.818853  687.128278  1047.504588
# 91 2020-12-09  823.022642  646.642025   989.296269
# 92 2020-12-10  841.528760  665.055622  1025.036301

# %%
fig1 = m.plot(prophet_pred)

# %%
fig2 = m.plot_components(prophet_pred)

# %%
prophet_pred = pd.DataFrame({"Date" : prophet_pred[-10:]['ds'], "Pred" : prophet_pred[-10:]["yhat"]})
prophet_pred = prophet_pred.set_index("Date")
prophet_pred
# Out:
#                   Pred
# Date
# 2020-12-01  798.860200
# 2020-12-02  760.063989
# 2020-12-03  778.570107
# 2020-12-04  833.594966
# 2020-12-05  811.965852
# 2020-12-06  738.942483
# 2020-12-07  731.135316
# 2020-12-08  861.818853
# 2020-12-09  823.022642
# 2020-12-10  841.528760

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ds'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-107a8dd38561> in <module>
# ----> 1 fig1 = m.plot(prophet_pred)
#
# /usr/local/lib/python3.8/site-packages/fbprophet/forecaster.py in plot(self, fcst, ax, uncertainty, plot_cap, xlabel, ylabel, figsize)
#    1590         A matplotlib figure.
#    1591         """
# -> 1592         return plot(
#    1593             m=self, fcst=fcst, ax=ax, uncertainty=uncertainty,
#    1594             plot_cap=plot_cap, xlabel=xlabel, ylabel=ylabel,
#
# /usr/local/lib/python3.8/site-packages/fbprophet/plot.py in plot(m, fcst, ax, uncertainty, plot_cap, xlabel, ylabel, figsize)
#      68     else:
#      69         fig = ax.get_figure()
# ---> 70     fcst_t = fcst['ds'].dt.to_pydatetime()
#      71     ax.plot(m.history['ds'].dt.to_pydatetime(), m.history['y'], 'k.')
#      72     ax.plot(fcst_t, fcst['yhat'], ls='-', c='#0072B2')
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'ds'

# %%
fig2 = m.plot_components(prophet_pred)

# %%
test_data["Prophet_Predictions"] = prophet_pred['Pred'].values
plt.figure(figsize=(16,5))
ax = sns.lineplot(x= test_data.index, y=test_data["y"])
sns.lineplot(x=test_data.index, y = test_data["Prophet_Predictions"]);

# %% [markdown]
# #### The blue line represents dialy new Covid cases in St. Louis County and the orange line represents Prophet Predictions.

# %%
mae_error = mean_absolute_error(test_data['y'], test_data["Prophet_Predictions"])
mse_error = mean_squared_error(test_data['y'], test_data["Prophet_Predictions"])
rmse_error = np.sqrt(mse_error)
mean_value = df['County'].mean()

print(f'MAE Error: {mae_error} \nMSE Error: {mse_error}\nRMSE Error: {rmse_error}\nMean: {mean_value}')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Prophet_Predictions'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-9626badbf2cb> in <module>
# ----> 1 mae_error = mean_absolute_error(test_data['y'], test_data["Prophet_Predictions"])
#       2 mse_error = mean_squared_error(test_data['y'], test_data["Prophet_Predictions"])
#       3 rmse_error = np.sqrt(mse_error)
#       4 mean_value = df['County'].mean()
#       5
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2897             if self.columns.nlevels > 1:
#    2898                 return self._getitem_multilevel(key)
# -> 2899             indexer = self.columns.get_loc(key)
#    2900             if is_integer(indexer):
#    2901                 indexer = [indexer]
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'Prophet_Predictions'
